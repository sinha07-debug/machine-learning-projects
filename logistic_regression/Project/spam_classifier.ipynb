# %% [markdown]
# # **Spam Classifier (Logistic Regression from Scratch)**
# Binary classification model for detecting spam messages using:
#
# - Logistic regression
# - Cross-entropy loss
# - Gradient descent
# - Evaluation metrics (precision, recall)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from collections import Counter
import re

# %%
#load the dataset
df = pd.read_csv("spam.csv", encoding='latin-1')[['v1','v2']]
df
# Out:
#         v1                                                 v2
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham              Will Ì_ b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
df.columns = ['label', 'message']
df['label'] = df['label'].str.strip().str.lower()
df['label'] = df['label'].map({'ham': 0, 'spam': 1})
df
# Out:
#       label                                            message
# 0         0  Go until jurong point, crazy.. Available only ...
# 1         0                      Ok lar... Joking wif u oni...
# 2         1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         0  U dun say so early hor... U c already then say...
# 4         0  Nah I don't think he goes to usf, he lives aro...
# ...     ...                                                ...
# 5567      1  This is the 2nd time we have tried 2 contact u...
# 5568      0              Will Ì_ b going to esplanade fr home?
# 5569      0  Pity, * was in mood for that. So...any other s...
# 5570      0  The guy did some bitching but I acted like i'd...
# 5571      0                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
spam = df[df['label'] == 1]
ham = df[df['label'] == 0] #creates 2 datasets

ham_sampled = ham.sample(len(spam), random_state=42)

df = pd.concat([spam, ham_sampled]) #combine the datasets
df = df.sample(frac=1, random_state=42).reset_index(drop=True) #shuffle data set

# %%
print(df.shape)
print(df['label'].value_counts())
# Out:
# (1494, 2)
# label
# 0    747
# 1    747
# Name: count, dtype: int64

# %%
#data cleaing i.e. texts
def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z0-9\s]','', text)
    return text

df['cleaned_msg'] = df['message'].apply(clean_text)
df
# Out:
#       label                                            message  \
# 0         0  Come to mu, we're sorting out our narcotics si...
# 1         0  We can go 4 e normal pilates after our intro...
# 2         0            Have you laid your airtel line to rest?
# 3         0                   Gokila is talking with you aha:)
# 4         0                    We confirm eating at esplanade?
# ...     ...                                                ...
# 1489      0                 I'm in a meeting, call me later at
# 1490      0                        S da..al r above  &lt;#&gt;
# 1491      0  Love isn't a decision, it's a feeling. If we c...
# 1492      0  Wat makes some people dearer is not just de ha...
# 1493      0  Good afternoon, my love ! Any job prospects ? ...
#
#                                             cleaned_msg
# 0     come to mu were sorting out our narcotics situ...
# 1        we can go 4 e normal pilates after our intro
# 2                have you laid your airtel line to rest
# 3                        gokila is talking with you aha
# 4                        we confirm eating at esplanade
# ...                                                 ...
# 1489                   im in a meeting call me later at
# 1490                               s daal r above  ltgt
# 1491  love isnt a decision its a feeling if we could...
# 1492  wat makes some people dearer is not just de ha...
# 1493  good afternoon my love  any job prospects  are...
#
# [1494 rows x 3 columns]

# %%
#limited vocab
all_words= []
for text in df['cleaned_msg']:
    all_words.extend(text.split())

common_words = Counter(all_words).most_common(1000)
common_words
# Out:
# [('to', 906),
#  ('you', 601),
#  ('a', 533),
#  ('call', 390),
#  ('i', 383),
#  ('the', 380),
#  ('your', 328),
#  ('u', 300),
#  ('is', 277),
#  ('and', 272),
#  ('for', 268),
#  ('now', 228),
#  ('free', 221),
#  ('or', 220),
#  ('2', 212),
#  ('in', 204),
#  ('have', 203),
#  ('on', 199),
#  ('of', 184),
#  ('ur', 180),
#  ('with', 152),
#  ('txt', 152),
#  ('from', 151),
#  ('my', 146),
#  ('4', 143),
#  ('are', 143),
#  ('me', 136),
#  ('text', 129),
#  ('this', 129),
#  ('get', 125),
#  ('mobile', 124),
#  ('stop', 120),
#  ('just', 118),
#  ('that', 117),
#  ('it', 114),
#  ('claim', 113),
#  ('reply', 108),
#  ('no', 100),
#  ('so', 99),
#  ('only', 96),
#  ('our', 95),
#  ('prize', 92),
#  ('be', 92),
#  ('we', 89),
#  ('at', 88),
#  ('will', 88),
#  ('not', 87),
#  ('send', 87),
#  ('can', 86),
#  ('out', 82),
#  ('new', 80),
#  ('if', 80),
#  ('dont', 73),
#  ('won', 73),
#  ('go', 72),
#  ('do', 70),
#  ('please', 70),
#  ('up', 69),
#  ('im', 68),
#  ('cash', 65),
#  ('nokia', 65),
#  ('phone', 64),
#  ('win', 64),
#  ('urgent', 64),
#  ('who', 60),
#  ('contact', 59),
#  ('but', 58),
#  ('what', 58),
#  ('know', 58),
#  ('all', 57),
#  ('want', 56),
#  ('week', 56),
#  ('its', 56),
#  ('been', 55),
#  ('when', 55),
#  ('service', 55),
#  ('as', 55),
#  ('how', 52),
#  ('by', 51),
#  ('guaranteed', 50),
#  ('16', 49),
#  ('customer', 49),
#  ('tone', 48),
#  ('per', 47),
#  ('has', 47),
#  ('like', 47),
#  ('good', 47),
#  ('1', 45),
#  ('love', 45),
#  ('500', 44),
#  ('chat', 44),
#  ('ok', 44),
#  ('more', 44),
#  ('number', 43),
#  ('18', 43),
#  ('r', 42),
#  ('back', 41),
#  ('time', 41),
#  ('1000', 41),
#  ('any', 40),
#  ('msg', 40),
#  ('there', 40),
#  ('then', 40),
#  ('day', 40),
#  ('am', 39),
#  ('message', 39),
#  ('draw', 39),
#  ('150', 39),
#  ('got', 39),
#  ('ltgt', 39),
#  ('mins', 38),
#  ('100', 38),
#  ('awarded', 38),
#  ('latest', 38),
#  ('ill', 38),
#  ('every', 37),
#  ('see', 37),
#  ('hi', 37),
#  ('was', 37),
#  ('line', 36),
#  ('tell', 35),
#  ('3', 34),
#  ('150ppm', 34),
#  ('2000', 34),
#  ('camera', 34),
#  ('shows', 34),
#  ('an', 34),
#  ('they', 33),
#  ('landline', 33),
#  ('receive', 33),
#  ('sorry', 33),
#  ('box', 32),
#  ('dear', 32),
#  ('about', 32),
#  ('holiday', 32),
#  ('one', 31),
#  ('need', 31),
#  ('n', 30),
#  ('take', 30),
#  ('chance', 30),
#  ('apply', 30),
#  ('video', 29),
#  ('live', 29),
#  ('po', 29),
#  ('c', 29),
#  ('had', 29),
#  ('sms', 29),
#  ('well', 29),
#  ('tcs', 29),
#  ('code', 29),
#  ('come', 28),
#  ('today', 28),
#  ('1st', 28),
#  ('orange', 28),
#  ('award', 28),
#  ('her', 28),
#  ('later', 28),
#  ('network', 27),
#  ('ringtone', 27),
#  ('collection', 26),
#  ('entry', 26),
#  ('find', 26),
#  ('give', 26),
#  ('where', 26),
#  ('he', 25),
#  ('why', 25),
#  ('yes', 25),
#  ('offer', 25),
#  ('great', 25),
#  ('selected', 25),
#  ('last', 25),
#  ('still', 25),
#  ('tones', 25),
#  ('cost', 24),
#  ('mob', 24),
#  ('here', 24),
#  ('5000', 24),
#  ('next', 24),
#  ('word', 24),
#  ('going', 24),
#  ('weekly', 24),
#  ('pls', 24),
#  ('150p', 23),
#  ('valid', 23),
#  ('some', 23),
#  ('cant', 23),
#  ('sent', 23),
#  ('collect', 23),
#  ('over', 23),
#  ('help', 23),
#  ('hey', 23),
#  ('attempt', 22),
#  ('2nd', 22),
#  ('waiting', 22),
#  ('800', 22),
#  ('delivery', 21),
#  ('8007', 21),
#  ('miss', 21),
#  ('250', 21),
#  ('music', 21),
#  ('play', 21),
#  ('she', 21),
#  ('tomorrow', 21),
#  ('tc', 21),
#  ('sae', 21),
#  ('account', 21),
#  ('think', 21),
#  ('make', 21),
#  ('bonus', 21),
#  ('were', 20),
#  ('e', 20),
#  ('price', 20),
#  ('vouchers', 20),
#  ('place', 20),
#  ('update', 20),
#  ('todays', 20),
#  ('thats', 20),
#  ('night', 20),
#  ('home', 20),
#  ('rate', 20),
#  ('wat', 20),
#  ('gift', 20),
#  ('thanks', 20),
#  ('texts', 20),
#  ('750', 19),
#  ('half', 19),
#  ('club', 19),
#  ('would', 19),
#  ('sexy', 19),
#  ('d', 19),
#  ('name', 19),
#  ('86688', 19),
#  ('xmas', 19),
#  ('should', 19),
#  ('someone', 19),
#  ('trying', 19),
#  ('await', 19),
#  ('lor', 19),
#  ('b', 19),
#  ('end', 18),
#  ('land', 18),
#  ('special', 18),
#  ('tscs', 18),
#  ('double', 18),
#  ('pounds', 18),
#  ('s', 18),
#  ('tried', 18),
#  ('points', 18),
#  ('keep', 18),
#  ('private', 18),
#  ('hope', 18),
#  ('unsubscribe', 18),
#  ('12hrs', 17),
#  ('min', 17),
#  ('real', 17),
#  ('final', 17),
#  ('colour', 17),
#  ('expires', 17),
#  ('top', 17),
#  ('poly', 17),
#  ('days', 17),
#  ('services', 17),
#  ('join', 17),
#  ('happy', 17),
#  ('may', 17),
#  ('morning', 17),
#  ('did', 17),
#  ('which', 17),
#  ('08000930705', 16),
#  ('voucher', 16),
#  ('wk', 16),
#  ('games', 16),
#  ('too', 16),
#  ('doing', 16),
#  ('mobileupd8', 16),
#  ('dating', 16),
#  ('babe', 16),
#  ('lol', 16),
#  ('winner', 16),
#  ('care', 16),
#  ('statement', 16),
#  ('unredeemed', 16),
#  ('identifier', 16),
#  ('being', 16),
#  ('us', 16),
#  ('could', 16),
#  ('oh', 16),
#  ('pobox', 16),
#  ('auction', 16),
#  ('wanna', 16),
#  ('already', 16),
#  ('ask', 16),
#  ('let', 16),
#  ('after', 15),
#  ('hot', 15),
#  ('uk', 15),
#  ('ltd', 15),
#  ('yours', 15),
#  ('08000839402', 15),
#  ('x', 15),
#  ('150pmsg', 15),
#  ('much', 15),
#  ('easy', 15),
#  ('camcorder', 15),
#  ('order', 15),
#  ('350', 15),
#  ('da', 15),
#  ('operator', 15),
#  ('important', 15),
#  ('right', 15),
#  ('money', 15),
#  ('congratulations', 14),
#  ('wkly', 14),
#  ('ready', 14),
#  ('first', 14),
#  ('calls', 14),
#  ('cs', 14),
#  ('mates', 14),
#  ('work', 14),
#  ('between', 14),
#  ('10p', 14),
#  ('thought', 14),
#  ('weeks', 14),
#  ('content', 14),
#  ('speak', 14),
#  ('friend', 14),
#  ('him', 14),
#  ('best', 14),
#  ('pics', 14),
#  ('before', 14),
#  ('part', 13),
#  ('hello', 13),
#  ('87066', 13),
#  ('txts', 13),
#  ('worth', 13),
#  ('savamob', 13),
#  ('offers', 13),
#  ('t', 13),
#  ('them', 13),
#  ('xxx', 13),
#  ('opt', 13),
#  ('quiz', 13),
#  ('0800', 13),
#  ('2003', 13),
#  ('amp', 13),
#  ('5', 13),
#  ('use', 13),
#  ('phones', 13),
#  ('feel', 13),
#  ('meet', 13),
#  ('wish', 13),
#  ('try', 13),
#  ('life', 13),
#  ('game', 13),
#  ('charge', 13),
#  ('anytime', 12),
#  ('rental', 12),
#  ('year', 12),
#  ('ipod', 12),
#  ('friends', 12),
#  ('player', 12),
#  ('talk', 12),
#  ('things', 12),
#  ('re', 12),
#  ('mobiles', 12),
#  ('weekend', 12),
#  ('300', 12),
#  ('theres', 12),
#  ('enjoy', 12),
#  ('valued', 12),
#  ('didnt', 12),
#  ('200', 12),
#  ('also', 12),
#  ('way', 12),
#  ('welcome', 12),
#  ('m', 12),
#  ('guess', 12),
#  ('national', 12),
#  ('enter', 12),
#  ('soon', 12),
#  ('even', 12),
#  ('complimentary', 12),
#  ('eg', 12),
#  ('said', 12),
#  ('into', 12),
#  ('pick', 12),
#  ('told', 12),
#  ('something', 12),
#  ('caller', 12),
#  ('freemsg', 12),
#  ('either', 11),
#  ('plus', 11),
#  ('congrats', 11),
#  ('motorola', 11),
#  ('unlimited', 11),
#  ('numbers', 11),
#  ('thing', 11),
#  ('10', 11),
#  ('start', 11),
#  ('yr', 11),
#  ('late', 11),
#  ('calling', 11),
#  ('buy', 11),
#  ('dogging', 11),
#  ('away', 11),
#  ('guys', 11),
#  ('heart', 11),
#  ('details', 11),
#  ('12', 11),
#  ('very', 11),
#  ('charged', 11),
#  ('ive', 11),
#  ('choose', 11),
#  ('leave', 11),
#  ('around', 11),
#  ('luv', 11),
#  ('messages', 11),
#  ('sex', 11),
#  ('years', 11),
#  ('news', 11),
#  ('off', 11),
#  ('looking', 11),
#  ('currently', 11),
#  ('ntt', 10),
#  ('his', 10),
#  ('fun', 10),
#  ('say', 10),
#  ('girl', 10),
#  ('ldn', 10),
#  ('enough', 10),
#  ('representative', 10),
#  ('uks', 10),
#  ('reward', 10),
#  ('minutes', 10),
#  ('getting', 10),
#  ('wap', 10),
#  ('del', 10),
#  ('month', 10),
#  ('people', 10),
#  ('log', 10),
#  ('date', 10),
#  ('direct', 10),
#  ('txting', 10),
#  ('long', 10),
#  ('secret', 10),
#  ('admirer', 10),
#  ('thinks', 10),
#  ('pay', 10),
#  ('visit', 10),
#  ('really', 10),
#  ('pic', 10),
#  ('10pmin', 10),
#  ('shopping', 10),
#  ('comp', 10),
#  ('gr8', 10),
#  ('credit', 10),
#  ('same', 10),
#  ('hmv', 10),
#  ('optout', 9),
#  ('dat', 9),
#  ('person', 9),
#  ('wont', 9),
#  ('11mths', 9),
#  ('discount', 9),
#  ('other', 9),
#  ('bluetooth', 9),
#  ('ending', 9),
#  ('never', 9),
#  ('fancy', 9),
#  ('lucky', 9),
#  ('missing', 9),
#  ('another', 9),
#  ('put', 9),
#  ('answer', 9),
#  ('charity', 9),
#  ('within', 9),
#  ('wwwgetzedcouk', 9),
#  ('6', 9),
#  ('youre', 9),
#  ('dis', 9),
#  ('credits', 9),
#  ('class', 9),
#  ('england', 9),
#  ('flag', 9),
#  ('gud', 9),
#  ('yeah', 9),
#  ('area', 9),
#  ('minute', 9),
#  ('break', 9),
#  ('std', 9),
#  ('rates', 9),
#  ('age', 9),
#  ('each', 9),
#  ('reach', 9),
#  ('asked', 9),
#  ('missed', 9),
#  ('specially', 9),
#  ('hear', 8),
#  ('shop', 8),
#  ('3030', 8),
#  ('v', 8),
#  ('etc', 8),
#  ('look', 8),
#  ('cd', 8),
#  ('inc', 8),
#  ('man', 8),
#  ('entitled', 8),
#  ('again', 8),
#  ('plz', 8),
#  ('b4', 8),
#  ('many', 8),
#  ('check', 8),
#  ('info', 8),
#  ('2004', 8),
#  ('problem', 8),
#  ('trip', 8),
#  ('asap', 8),
#  ('computer', 8),
#  ('ans', 8),
#  ('hours', 8),
#  ('went', 8),
#  ('weekends', 8),
#  ('matches', 8),
#  ('25p', 8),
#  ('polys', 8),
#  ('btnationalrate', 8),
#  ('no1', 8),
#  ('hgsuite3422lands', 8),
#  ('until', 8),
#  ('address', 8),
#  ('information', 8),
#  ('user', 8),
#  ('surprise', 8),
#  ('awaiting', 8),
#  ('since', 8),
#  ('anything', 8),
#  ('sony', 8),
#  ('summer', 8),
#  ('match', 8),
#  ('sir', 8),
#  ('ufind', 8),
#  ('rreveal', 8),
#  ('specialcall', 8),
#  ('store', 8),
#  ('down', 8),
#  ('terms', 8),
#  ('freephone', 8),
#  ('cos', 8),
#  ('sunshine', 8),
#  ('eat', 8),
#  ('lunch', 8),
#  ('87077', 8),
#  ('yup', 8),
#  ('digital', 8),
#  ('horny', 7),
#  ('150pm', 7),
#  ('custcare', 7),
#  ('uve', 7),
#  ('f', 7),
#  ('invited', 7),
#  ('85023', 7),
#  ('sub', 7),
#  ('wid', 7),
#  ('thank', 7),
#  ('baby', 7),
#  ('wait', 7),
#  ('dvd', 7),
#  ('must', 7),
#  ('loyalty', 7),
#  ('sure', 7),
#  ('rcvd', 7),
#  ('entered', 7),
#  ('saturday', 7),
#  ('tenerife', 7),
#  ('than', 7),
#  ('movie', 7),
#  ('extra', 7),
#  ('900', 7),
#  ('400', 7),
#  ('pc', 7),
#  ('nothing', 7),
#  ('does', 7),
#  ('costa', 7),
#  ('sol', 7),
#  ('sk38xh', 7),
#  ('lose', 7),
#  ('thk', 7),
#  ('happen', 7),
#  ('registered', 7),
#  ('wake', 7),
#  ('eve', 7),
#  ('10000', 7),
#  ('gay', 7),
#  ('36504', 7),
#  ('without', 7),
#  ('better', 7),
#  ('needs', 7),
#  ('ring', 7),
#  ('20p', 7),
#  ('1327', 7),
#  ('croydon', 7),
#  ('cr9', 7),
#  ('5wb', 7),
#  ('onto', 7),
#  ('fantastic', 7),
#  ('450', 7),
#  ('always', 7),
#  ('means', 7),
#  ('08712460324', 7),
#  ('came', 7),
#  ('nice', 7),
#  ('wan', 7),
#  ('ever', 7),
#  ('gonna', 7),
#  ('takes', 7),
#  ('flirt', 7),
#  ('y', 7),
#  ('meeting', 7),
#  ('spree', 7),
#  ('smile', 7),
#  ('crazy', 7),
#  ('comes', 7),
#  ('access', 7),
#  ('whats', 7),
#  ('jus', 7),
#  ('close', 7),
#  ('cashbalance', 7),
#  ('maximize', 7),
#  ('cashin', 7),
#  ('de', 7),
#  ('yesterday', 7),
#  ('bid', 7),
#  ('pm', 7),
#  ('months', 6),
#  ('local', 6),
#  ('vary', 6),
#  ('40gb', 6),
#  ('tncs', 6),
#  ('msgs', 6),
#  ('cancel', 6),
#  ('hl', 6),
#  ('tariffs', 6),
#  ('remove', 6),
#  ('50', 6),
#  ('true', 6),
#  ('g', 6),
#  ('mind', 6),
#  ('bt', 6),
#  ('vodafone', 6),
#  ('holder', 6),
#  ('thanx', 6),
#  ('goto', 6),
#  ('tv', 6),
#  ('bad', 6),
#  ('09050090044', 6),
#  ('toclaim', 6),
#  ('pobox334', 6),
#  ('stockport', 6),
#  ('cost150pm', 6),
#  ('max10mins', 6),
#  ('haha', 6),
#  ('08712300220', 6),
#  ('zed', 6),
#  ('luck', 6),
#  ('pound', 6),
#  ('watching', 6),
#  ('case', 6),
#  ('link', 6),
#  ('w45wq', 6),
#  ('norm150ptone', 6),
#  ('sleep', 6),
#  ('noe', 6),
#  ('shes', 6),
#  ('those', 6),
#  ('ends', 6),
#  ('86021', 6),
#  ('fantasies', 6),
#  ('08707509020', 6),
#  ('lost', 6),
#  ('httpwwwurawinnercom', 6),
#  ('arrive', 6),
#  ('7', 6),
#  ('these', 6),
#  ('left', 6),
#  ('inviting', 6),
#  ('frnd', 6),
#  ('62468', 6),
#  ('yet', 6),
#  ('watch', 6),
#  ('0870', 6),
#  ('early', 6),
#  ('while', 6),
#  ('princess', 6),
#  ('ah', 6),
#  ('post', 6),
#  ('1000s', 6),
#  ('car', 6),
#  ('job', 6),
#  ('goes', 6),
#  ('standard', 6),
#  ('plan', 6),
#  ('announcement', 6),
#  ('activate', 6),
#  ('lets', 6),
#  ('cool', 6),
#  ('little', 6),
#  ('pobox84', 6),
#  ('cc', 6),
#  ('show', 6),
#  ('arcade', 6),
#  ('lar', 6),
#  ('questions', 6),
#  ('bill', 6),
#  ('replying', 6),
#  ('flights', 6),
#  ('sipix', 6),
#  ('handset', 6),
#  ('login', 6),
#  ('confirm', 5),
#  ('drop', 5),
#  ('eerie', 5),
#  ('card', 5),
#  ('spook', 5),
#  ('wow', 5),
#  ('juz', 5),
#  ('cinema', 5),
#  ('pass', 5),
#  ('cum', 5),
#  ('150ptone', 5),
#  ('contract', 5),
#  ('11', 5),
#  ('records', 5),
#  ('wen', 5),
#  ('believe', 5),
#  ('set', 5),
#  ('maybe', 5),
#  ('xchat', 5),
#  ('k', 5),
#  ('na', 5),
#  ('member', 5),
#  ('unsub', 5),
#  ('3g', 5),
#  ('videophones', 5),
#  ('videochat', 5),
#  ('java', 5),
#  ('dload', 5),
#  ('noline', 5),
#  ('rentl', 5),
#  ('ip4', 5),
#  ('5we', 5),
#  ('their', 5),
#  ('sonyericsson', 5),
#  ('hows', 5),
#  ('partner', 5),
#  ('because', 5),
#  ('picked', 5),
#  ('via', 5),
#  ('fast', 5),
#  ('bring', 5),
#  ('3510i', 5),
#  ('pub', 5),
#  ('okie', 5),
#  ('download', 5),
#  ('loan', 5),
#  ('fone', 5),
#  ('read', 5),
#  ('stay', 5),
#  ('future', 5),
#  ('4u', 5),
#  ('tonight', 5),
#  ('locations', 5),
#  ('family', 5),
#  ('town', 5),
#  ('polyphonic', 5),
#  ('coming', 5),
#  ('following', 5),
#  ('age16', 5),
#  ('rply', 5),
#  ('pobox36504w45wq', 5),
#  ('sim', 5),
#  ('brand', 5),
#  ('room', 5),
#  ('god', 5),
#  ('yourself', 5),
#  ('bored', 5),
#  ('stuff', 5),
#  ('neva', 5),
#  ('sis', 5),
#  ('huh', 5),
#  ('mp3', 5),
#  ('reference', 5),
#  ('few', 5),
#  ('1x150pwk', 5),
#  ('youve', 5),
#  ('cup', 5),
#  ('shit', 5),
#  ('myself', 5),
#  ('once', 5),
#  ('aight', 5),
#  ('hand', 5),
#  ('sort', 5),
#  ('2nite', 5),
#  ('december', 5),
#  ('okay', 5),
#  ('forwarded', 5),
#  ('immediately', 5),
#  ('story', 5),
#  ('official', 5),
#  ('gods', 5),
#  ('sport', 5),
#  ('walk', 5),
#  ('selection', 5),
#  ('singles', 5),
#  ('sale', 5),
#  ('fri', 5),
#  ('sat', 5),
#  ('made', 5),
#  ('hour', 5),
#  ('review', 5),
#  ('voda', 5),
#  ('quoting', 5),
#  ('revealed', 5),
#  ('boy', 5),
#  ('linerental', 5),
#  ('abt', 5),
#  ('dun', 5),
#  ('park', 5),
#  ('hard', 5),
#  ('cheap', 5),
#  ('moms', 5),
#  ('liao', 5),
#  ('leh', 5),
#  ('hospital', 5),
#  ('girls', 5),
#  ('starts', 5),
#  ('ringtones', 5),
#  ('two', 5),
#  ('82277', 5),
#  ('xx', 5),
#  ('wife', 5),
#  ('most', 5),
#  ('email', 5),
#  ('08718720201', 5),
#  ('sweet', 5),
#  ('euro2004', 5),
#  ('dunno', 5),
#  ('ten', 5),
#  ('question', 5),
#  ('o2', 5),
#  ('lot', 5),
#  ('everything', 5),
#  ('everyone', 5),
#  ('28', 5),
#  ('9', 5),
#  ('co', 5),
#  ('contacted', 5),
#  ('fantasy', 5),
#  ('click', 5),
#  ('8', 5),
#  ('fuck', 5),
#  ('80062', 5),
#  ('book', 5),
#  ('else', 5),
#  ('cds', 5),
#  ('dream', 5),
#  ('big', 5),
#  ('feeling', 5),
#  ('inclusive', 5),
#  ('wwwcomuknet', 5),
#  ('mu', 4),
#  ('laid', 4),
#  ('eating', 4),
#  ('netcollex', 4),
#  ('till', 4),
#  ('boys', 4),
#  ('tour', 4),
#  ('vip', 4),
#  ('tickets', 4),
#  ('08712405020', 4),
#  ('wwwldewcom1win150ppmx3age16', 4),
#  ('porn', 4),
#  ('txtin', 4),
#  ('4info', 4),
#  ('flower', 4),
#  ('alright', 4),
#  ('150pmsgrcvdhgsuite3422landsroww1j6hl', 4),
#  ('freefone', 4),
#  ('boytoy', 4),
#  ('bx420', 4),
#  ('places', 4),
#  ('telling', 4),
#  ('2day', 4),
#  ('bus', 4),
#  ('2optout', 4),
#  ('txtauction', 4),
#  ('complete', 4),
#  ('10am7pm', 4),
#  ('valentines', 4),
#  ('83600', 4),
#  ('guy', 4),
#  ('used', 4),
#  ('wanted', 4),
#  ('notice', 4),
#  ('cw25wx', 4),
#  ('delivered', 4),
#  ('moby', 4),
#  ('high', 4),
#  ('street', 4),
#  ('pa', 4),
#  ('purpose', 4),
#  ('tenants', 4),
#  ('refused', 4),
#  ('lots', 4),
#  ('medical', 4),
#  ('safe', 4),
#  ('omg', 4),
#  ('shall', 4),
#  ('den', 4),
#  ('wrong', 4),
#  ('num', 4),
#  ('pleased', 4),
#  ('urn', 4),
#  ('ac', 4),
#  ('largest', 4),
#  ('ec2a', 4),
#  ('daily', 4),
#  ('birthday', 4),
#  ('reveal', 4),
#  ('cust', 4),
#  ('simply', 4),
#  ('ibiza', 4),
#  ('starting', 4),
#  ('yar', 4),
#  ('mths', 4),
#  ('ntwk', 4),
#  ('08001950382', 4),
#  ('bahamas', 4),
#  ('aft', 4),
#  ('fine', 4),
#  ('makes', 4),
#  ('bed', 4),
#  ('fucking', 4),
#  ('87131', 4),
#  ('7250i', 4),
#  ('roww1jhl', 4),
#  ('83355', 4),
#  ('added', 4),
#  ('action', 4),
#  ('150pmin', 4),
#  ('world', 4),
#  ('87239', 4),
#  ('tot', 4),
#  ('saying', 4),
#  ('87121', 4),
#  ('fr', 4),
#  ('fact', 4),
#  ('yo', 4),
#  ('full', 4),
#  ('available', 4),
#  ('heard', 4),
#  ('pix', 4),
#  ('8552', 4),
#  ('cause', 4),
#  ('wiv', 4),
#  ('started', 4),
#  ('hav', 4),
#  ('forgot', 4),
#  ('done', 4),
#  ('yer', 4),
#  ('84199', 4),
#  ('eng', 4),
#  ('box39822', 4),
#  ('w111wx', 4),
#  ('straight', 4),
#  ('rooms', 4),
#  ('both', 4),
#  ('3wk', 4),
#  ('hit', 4),
#  ('actually', 4),
#  ('kept', 4),
#  ('touch', 4),
#  ('unable', 4),
#  ('lover', 4),
#  ('1500', 4),
#  ('pod', 4),
#  ('app', 4),
#  ('exciting', 4),
#  ('sign', 4),
#  ('men', 4),
#  ('super', 4),
#  ('542', 4),
#  ('run', 4),
#  ('urgnt', 4),
#  ('020603', 4),
#  ('0808', 4),
#  ('145', 4),
#  ('4742', 4),
#  ('9am11pm', 4),
#  ('85', 4),
#  ('wc1n3xx', 4)]

# %%
vocab = {word: i for i, (word, _) in enumerate(common_words)}
vocab
# Out:
# {'to': 0,
#  'you': 1,
#  'a': 2,
#  'call': 3,
#  'i': 4,
#  'the': 5,
#  'your': 6,
#  'u': 7,
#  'is': 8,
#  'and': 9,
#  'for': 10,
#  'now': 11,
#  'free': 12,
#  'or': 13,
#  '2': 14,
#  'in': 15,
#  'have': 16,
#  'on': 17,
#  'of': 18,
#  'ur': 19,
#  'with': 20,
#  'txt': 21,
#  'from': 22,
#  'my': 23,
#  '4': 24,
#  'are': 25,
#  'me': 26,
#  'text': 27,
#  'this': 28,
#  'get': 29,
#  'mobile': 30,
#  'stop': 31,
#  'just': 32,
#  'that': 33,
#  'it': 34,
#  'claim': 35,
#  'reply': 36,
#  'no': 37,
#  'so': 38,
#  'only': 39,
#  'our': 40,
#  'prize': 41,
#  'be': 42,
#  'we': 43,
#  'at': 44,
#  'will': 45,
#  'not': 46,
#  'send': 47,
#  'can': 48,
#  'out': 49,
#  'new': 50,
#  'if': 51,
#  'dont': 52,
#  'won': 53,
#  'go': 54,
#  'do': 55,
#  'please': 56,
#  'up': 57,
#  'im': 58,
#  'cash': 59,
#  'nokia': 60,
#  'phone': 61,
#  'win': 62,
#  'urgent': 63,
#  'who': 64,
#  'contact': 65,
#  'but': 66,
#  'what': 67,
#  'know': 68,
#  'all': 69,
#  'want': 70,
#  'week': 71,
#  'its': 72,
#  'been': 73,
#  'when': 74,
#  'service': 75,
#  'as': 76,
#  'how': 77,
#  'by': 78,
#  'guaranteed': 79,
#  '16': 80,
#  'customer': 81,
#  'tone': 82,
#  'per': 83,
#  'has': 84,
#  'like': 85,
#  'good': 86,
#  '1': 87,
#  'love': 88,
#  '500': 89,
#  'chat': 90,
#  'ok': 91,
#  'more': 92,
#  'number': 93,
#  '18': 94,
#  'r': 95,
#  'back': 96,
#  'time': 97,
#  '1000': 98,
#  'any': 99,
#  'msg': 100,
#  'there': 101,
#  'then': 102,
#  'day': 103,
#  'am': 104,
#  'message': 105,
#  'draw': 106,
#  '150': 107,
#  'got': 108,
#  'ltgt': 109,
#  'mins': 110,
#  '100': 111,
#  'awarded': 112,
#  'latest': 113,
#  'ill': 114,
#  'every': 115,
#  'see': 116,
#  'hi': 117,
#  'was': 118,
#  'line': 119,
#  'tell': 120,
#  '3': 121,
#  '150ppm': 122,
#  '2000': 123,
#  'camera': 124,
#  'shows': 125,
#  'an': 126,
#  'they': 127,
#  'landline': 128,
#  'receive': 129,
#  'sorry': 130,
#  'box': 131,
#  'dear': 132,
#  'about': 133,
#  'holiday': 134,
#  'one': 135,
#  'need': 136,
#  'n': 137,
#  'take': 138,
#  'chance': 139,
#  'apply': 140,
#  'video': 141,
#  'live': 142,
#  'po': 143,
#  'c': 144,
#  'had': 145,
#  'sms': 146,
#  'well': 147,
#  'tcs': 148,
#  'code': 149,
#  'come': 150,
#  'today': 151,
#  '1st': 152,
#  'orange': 153,
#  'award': 154,
#  'her': 155,
#  'later': 156,
#  'network': 157,
#  'ringtone': 158,
#  'collection': 159,
#  'entry': 160,
#  'find': 161,
#  'give': 162,
#  'where': 163,
#  'he': 164,
#  'why': 165,
#  'yes': 166,
#  'offer': 167,
#  'great': 168,
#  'selected': 169,
#  'last': 170,
#  'still': 171,
#  'tones': 172,
#  'cost': 173,
#  'mob': 174,
#  'here': 175,
#  '5000': 176,
#  'next': 177,
#  'word': 178,
#  'going': 179,
#  'weekly': 180,
#  'pls': 181,
#  '150p': 182,
#  'valid': 183,
#  'some': 184,
#  'cant': 185,
#  'sent': 186,
#  'collect': 187,
#  'over': 188,
#  'help': 189,
#  'hey': 190,
#  'attempt': 191,
#  '2nd': 192,
#  'waiting': 193,
#  '800': 194,
#  'delivery': 195,
#  '8007': 196,
#  'miss': 197,
#  '250': 198,
#  'music': 199,
#  'play': 200,
#  'she': 201,
#  'tomorrow': 202,
#  'tc': 203,
#  'sae': 204,
#  'account': 205,
#  'think': 206,
#  'make': 207,
#  'bonus': 208,
#  'were': 209,
#  'e': 210,
#  'price': 211,
#  'vouchers': 212,
#  'place': 213,
#  'update': 214,
#  'todays': 215,
#  'thats': 216,
#  'night': 217,
#  'home': 218,
#  'rate': 219,
#  'wat': 220,
#  'gift': 221,
#  'thanks': 222,
#  'texts': 223,
#  '750': 224,
#  'half': 225,
#  'club': 226,
#  'would': 227,
#  'sexy': 228,
#  'd': 229,
#  'name': 230,
#  '86688': 231,
#  'xmas': 232,
#  'should': 233,
#  'someone': 234,
#  'trying': 235,
#  'await': 236,
#  'lor': 237,
#  'b': 238,
#  'end': 239,
#  'land': 240,
#  'special': 241,
#  'tscs': 242,
#  'double': 243,
#  'pounds': 244,
#  's': 245,
#  'tried': 246,
#  'points': 247,
#  'keep': 248,
#  'private': 249,
#  'hope': 250,
#  'unsubscribe': 251,
#  '12hrs': 252,
#  'min': 253,
#  'real': 254,
#  'final': 255,
#  'colour': 256,
#  'expires': 257,
#  'top': 258,
#  'poly': 259,
#  'days': 260,
#  'services': 261,
#  'join': 262,
#  'happy': 263,
#  'may': 264,
#  'morning': 265,
#  'did': 266,
#  'which': 267,
#  '08000930705': 268,
#  'voucher': 269,
#  'wk': 270,
#  'games': 271,
#  'too': 272,
#  'doing': 273,
#  'mobileupd8': 274,
#  'dating': 275,
#  'babe': 276,
#  'lol': 277,
#  'winner': 278,
#  'care': 279,
#  'statement': 280,
#  'unredeemed': 281,
#  'identifier': 282,
#  'being': 283,
#  'us': 284,
#  'could': 285,
#  'oh': 286,
#  'pobox': 287,
#  'auction': 288,
#  'wanna': 289,
#  'already': 290,
#  'ask': 291,
#  'let': 292,
#  'after': 293,
#  'hot': 294,
#  'uk': 295,
#  'ltd': 296,
#  'yours': 297,
#  '08000839402': 298,
#  'x': 299,
#  '150pmsg': 300,
#  'much': 301,
#  'easy': 302,
#  'camcorder': 303,
#  'order': 304,
#  '350': 305,
#  'da': 306,
#  'operator': 307,
#  'important': 308,
#  'right': 309,
#  'money': 310,
#  'congratulations': 311,
#  'wkly': 312,
#  'ready': 313,
#  'first': 314,
#  'calls': 315,
#  'cs': 316,
#  'mates': 317,
#  'work': 318,
#  'between': 319,
#  '10p': 320,
#  'thought': 321,
#  'weeks': 322,
#  'content': 323,
#  'speak': 324,
#  'friend': 325,
#  'him': 326,
#  'best': 327,
#  'pics': 328,
#  'before': 329,
#  'part': 330,
#  'hello': 331,
#  '87066': 332,
#  'txts': 333,
#  'worth': 334,
#  'savamob': 335,
#  'offers': 336,
#  't': 337,
#  'them': 338,
#  'xxx': 339,
#  'opt': 340,
#  'quiz': 341,
#  '0800': 342,
#  '2003': 343,
#  'amp': 344,
#  '5': 345,
#  'use': 346,
#  'phones': 347,
#  'feel': 348,
#  'meet': 349,
#  'wish': 350,
#  'try': 351,
#  'life': 352,
#  'game': 353,
#  'charge': 354,
#  'anytime': 355,
#  'rental': 356,
#  'year': 357,
#  'ipod': 358,
#  'friends': 359,
#  'player': 360,
#  'talk': 361,
#  'things': 362,
#  're': 363,
#  'mobiles': 364,
#  'weekend': 365,
#  '300': 366,
#  'theres': 367,
#  'enjoy': 368,
#  'valued': 369,
#  'didnt': 370,
#  '200': 371,
#  'also': 372,
#  'way': 373,
#  'welcome': 374,
#  'm': 375,
#  'guess': 376,
#  'national': 377,
#  'enter': 378,
#  'soon': 379,
#  'even': 380,
#  'complimentary': 381,
#  'eg': 382,
#  'said': 383,
#  'into': 384,
#  'pick': 385,
#  'told': 386,
#  'something': 387,
#  'caller': 388,
#  'freemsg': 389,
#  'either': 390,
#  'plus': 391,
#  'congrats': 392,
#  'motorola': 393,
#  'unlimited': 394,
#  'numbers': 395,
#  'thing': 396,
#  '10': 397,
#  'start': 398,
#  'yr': 399,
#  'late': 400,
#  'calling': 401,
#  'buy': 402,
#  'dogging': 403,
#  'away': 404,
#  'guys': 405,
#  'heart': 406,
#  'details': 407,
#  '12': 408,
#  'very': 409,
#  'charged': 410,
#  'ive': 411,
#  'choose': 412,
#  'leave': 413,
#  'around': 414,
#  'luv': 415,
#  'messages': 416,
#  'sex': 417,
#  'years': 418,
#  'news': 419,
#  'off': 420,
#  'looking': 421,
#  'currently': 422,
#  'ntt': 423,
#  'his': 424,
#  'fun': 425,
#  'say': 426,
#  'girl': 427,
#  'ldn': 428,
#  'enough': 429,
#  'representative': 430,
#  'uks': 431,
#  'reward': 432,
#  'minutes': 433,
#  'getting': 434,
#  'wap': 435,
#  'del': 436,
#  'month': 437,
#  'people': 438,
#  'log': 439,
#  'date': 440,
#  'direct': 441,
#  'txting': 442,
#  'long': 443,
#  'secret': 444,
#  'admirer': 445,
#  'thinks': 446,
#  'pay': 447,
#  'visit': 448,
#  'really': 449,
#  'pic': 450,
#  '10pmin': 451,
#  'shopping': 452,
#  'comp': 453,
#  'gr8': 454,
#  'credit': 455,
#  'same': 456,
#  'hmv': 457,
#  'optout': 458,
#  'dat': 459,
#  'person': 460,
#  'wont': 461,
#  '11mths': 462,
#  'discount': 463,
#  'other': 464,
#  'bluetooth': 465,
#  'ending': 466,
#  'never': 467,
#  'fancy': 468,
#  'lucky': 469,
#  'missing': 470,
#  'another': 471,
#  'put': 472,
#  'answer': 473,
#  'charity': 474,
#  'within': 475,
#  'wwwgetzedcouk': 476,
#  '6': 477,
#  'youre': 478,
#  'dis': 479,
#  'credits': 480,
#  'class': 481,
#  'england': 482,
#  'flag': 483,
#  'gud': 484,
#  'yeah': 485,
#  'area': 486,
#  'minute': 487,
#  'break': 488,
#  'std': 489,
#  'rates': 490,
#  'age': 491,
#  'each': 492,
#  'reach': 493,
#  'asked': 494,
#  'missed': 495,
#  'specially': 496,
#  'hear': 497,
#  'shop': 498,
#  '3030': 499,
#  'v': 500,
#  'etc': 501,
#  'look': 502,
#  'cd': 503,
#  'inc': 504,
#  'man': 505,
#  'entitled': 506,
#  'again': 507,
#  'plz': 508,
#  'b4': 509,
#  'many': 510,
#  'check': 511,
#  'info': 512,
#  '2004': 513,
#  'problem': 514,
#  'trip': 515,
#  'asap': 516,
#  'computer': 517,
#  'ans': 518,
#  'hours': 519,
#  'went': 520,
#  'weekends': 521,
#  'matches': 522,
#  '25p': 523,
#  'polys': 524,
#  'btnationalrate': 525,
#  'no1': 526,
#  'hgsuite3422lands': 527,
#  'until': 528,
#  'address': 529,
#  'information': 530,
#  'user': 531,
#  'surprise': 532,
#  'awaiting': 533,
#  'since': 534,
#  'anything': 535,
#  'sony': 536,
#  'summer': 537,
#  'match': 538,
#  'sir': 539,
#  'ufind': 540,
#  'rreveal': 541,
#  'specialcall': 542,
#  'store': 543,
#  'down': 544,
#  'terms': 545,
#  'freephone': 546,
#  'cos': 547,
#  'sunshine': 548,
#  'eat': 549,
#  'lunch': 550,
#  '87077': 551,
#  'yup': 552,
#  'digital': 553,
#  'horny': 554,
#  '150pm': 555,
#  'custcare': 556,
#  'uve': 557,
#  'f': 558,
#  'invited': 559,
#  '85023': 560,
#  'sub': 561,
#  'wid': 562,
#  'thank': 563,
#  'baby': 564,
#  'wait': 565,
#  'dvd': 566,
#  'must': 567,
#  'loyalty': 568,
#  'sure': 569,
#  'rcvd': 570,
#  'entered': 571,
#  'saturday': 572,
#  'tenerife': 573,
#  'than': 574,
#  'movie': 575,
#  'extra': 576,
#  '900': 577,
#  '400': 578,
#  'pc': 579,
#  'nothing': 580,
#  'does': 581,
#  'costa': 582,
#  'sol': 583,
#  'sk38xh': 584,
#  'lose': 585,
#  'thk': 586,
#  'happen': 587,
#  'registered': 588,
#  'wake': 589,
#  'eve': 590,
#  '10000': 591,
#  'gay': 592,
#  '36504': 593,
#  'without': 594,
#  'better': 595,
#  'needs': 596,
#  'ring': 597,
#  '20p': 598,
#  '1327': 599,
#  'croydon': 600,
#  'cr9': 601,
#  '5wb': 602,
#  'onto': 603,
#  'fantastic': 604,
#  '450': 605,
#  'always': 606,
#  'means': 607,
#  '08712460324': 608,
#  'came': 609,
#  'nice': 610,
#  'wan': 611,
#  'ever': 612,
#  'gonna': 613,
#  'takes': 614,
#  'flirt': 615,
#  'y': 616,
#  'meeting': 617,
#  'spree': 618,
#  'smile': 619,
#  'crazy': 620,
#  'comes': 621,
#  'access': 622,
#  'whats': 623,
#  'jus': 624,
#  'close': 625,
#  'cashbalance': 626,
#  'maximize': 627,
#  'cashin': 628,
#  'de': 629,
#  'yesterday': 630,
#  'bid': 631,
#  'pm': 632,
#  'months': 633,
#  'local': 634,
#  'vary': 635,
#  '40gb': 636,
#  'tncs': 637,
#  'msgs': 638,
#  'cancel': 639,
#  'hl': 640,
#  'tariffs': 641,
#  'remove': 642,
#  '50': 643,
#  'true': 644,
#  'g': 645,
#  'mind': 646,
#  'bt': 647,
#  'vodafone': 648,
#  'holder': 649,
#  'thanx': 650,
#  'goto': 651,
#  'tv': 652,
#  'bad': 653,
#  '09050090044': 654,
#  'toclaim': 655,
#  'pobox334': 656,
#  'stockport': 657,
#  'cost150pm': 658,
#  'max10mins': 659,
#  'haha': 660,
#  '08712300220': 661,
#  'zed': 662,
#  'luck': 663,
#  'pound': 664,
#  'watching': 665,
#  'case': 666,
#  'link': 667,
#  'w45wq': 668,
#  'norm150ptone': 669,
#  'sleep': 670,
#  'noe': 671,
#  'shes': 672,
#  'those': 673,
#  'ends': 674,
#  '86021': 675,
#  'fantasies': 676,
#  '08707509020': 677,
#  'lost': 678,
#  'httpwwwurawinnercom': 679,
#  'arrive': 680,
#  '7': 681,
#  'these': 682,
#  'left': 683,
#  'inviting': 684,
#  'frnd': 685,
#  '62468': 686,
#  'yet': 687,
#  'watch': 688,
#  '0870': 689,
#  'early': 690,
#  'while': 691,
#  'princess': 692,
#  'ah': 693,
#  'post': 694,
#  '1000s': 695,
#  'car': 696,
#  'job': 697,
#  'goes': 698,
#  'standard': 699,
#  'plan': 700,
#  'announcement': 701,
#  'activate': 702,
#  'lets': 703,
#  'cool': 704,
#  'little': 705,
#  'pobox84': 706,
#  'cc': 707,
#  'show': 708,
#  'arcade': 709,
#  'lar': 710,
#  'questions': 711,
#  'bill': 712,
#  'replying': 713,
#  'flights': 714,
#  'sipix': 715,
#  'handset': 716,
#  'login': 717,
#  'confirm': 718,
#  'drop': 719,
#  'eerie': 720,
#  'card': 721,
#  'spook': 722,
#  'wow': 723,
#  'juz': 724,
#  'cinema': 725,
#  'pass': 726,
#  'cum': 727,
#  '150ptone': 728,
#  'contract': 729,
#  '11': 730,
#  'records': 731,
#  'wen': 732,
#  'believe': 733,
#  'set': 734,
#  'maybe': 735,
#  'xchat': 736,
#  'k': 737,
#  'na': 738,
#  'member': 739,
#  'unsub': 740,
#  '3g': 741,
#  'videophones': 742,
#  'videochat': 743,
#  'java': 744,
#  'dload': 745,
#  'noline': 746,
#  'rentl': 747,
#  'ip4': 748,
#  '5we': 749,
#  'their': 750,
#  'sonyericsson': 751,
#  'hows': 752,
#  'partner': 753,
#  'because': 754,
#  'picked': 755,
#  'via': 756,
#  'fast': 757,
#  'bring': 758,
#  '3510i': 759,
#  'pub': 760,
#  'okie': 761,
#  'download': 762,
#  'loan': 763,
#  'fone': 764,
#  'read': 765,
#  'stay': 766,
#  'future': 767,
#  '4u': 768,
#  'tonight': 769,
#  'locations': 770,
#  'family': 771,
#  'town': 772,
#  'polyphonic': 773,
#  'coming': 774,
#  'following': 775,
#  'age16': 776,
#  'rply': 777,
#  'pobox36504w45wq': 778,
#  'sim': 779,
#  'brand': 780,
#  'room': 781,
#  'god': 782,
#  'yourself': 783,
#  'bored': 784,
#  'stuff': 785,
#  'neva': 786,
#  'sis': 787,
#  'huh': 788,
#  'mp3': 789,
#  'reference': 790,
#  'few': 791,
#  '1x150pwk': 792,
#  'youve': 793,
#  'cup': 794,
#  'shit': 795,
#  'myself': 796,
#  'once': 797,
#  'aight': 798,
#  'hand': 799,
#  'sort': 800,
#  '2nite': 801,
#  'december': 802,
#  'okay': 803,
#  'forwarded': 804,
#  'immediately': 805,
#  'story': 806,
#  'official': 807,
#  'gods': 808,
#  'sport': 809,
#  'walk': 810,
#  'selection': 811,
#  'singles': 812,
#  'sale': 813,
#  'fri': 814,
#  'sat': 815,
#  'made': 816,
#  'hour': 817,
#  'review': 818,
#  'voda': 819,
#  'quoting': 820,
#  'revealed': 821,
#  'boy': 822,
#  'linerental': 823,
#  'abt': 824,
#  'dun': 825,
#  'park': 826,
#  'hard': 827,
#  'cheap': 828,
#  'moms': 829,
#  'liao': 830,
#  'leh': 831,
#  'hospital': 832,
#  'girls': 833,
#  'starts': 834,
#  'ringtones': 835,
#  'two': 836,
#  '82277': 837,
#  'xx': 838,
#  'wife': 839,
#  'most': 840,
#  'email': 841,
#  '08718720201': 842,
#  'sweet': 843,
#  'euro2004': 844,
#  'dunno': 845,
#  'ten': 846,
#  'question': 847,
#  'o2': 848,
#  'lot': 849,
#  'everything': 850,
#  'everyone': 851,
#  '28': 852,
#  '9': 853,
#  'co': 854,
#  'contacted': 855,
#  'fantasy': 856,
#  'click': 857,
#  '8': 858,
#  'fuck': 859,
#  '80062': 860,
#  'book': 861,
#  'else': 862,
#  'cds': 863,
#  'dream': 864,
#  'big': 865,
#  'feeling': 866,
#  'inclusive': 867,
#  'wwwcomuknet': 868,
#  'mu': 869,
#  'laid': 870,
#  'eating': 871,
#  'netcollex': 872,
#  'till': 873,
#  'boys': 874,
#  'tour': 875,
#  'vip': 876,
#  'tickets': 877,
#  '08712405020': 878,
#  'wwwldewcom1win150ppmx3age16': 879,
#  'porn': 880,
#  'txtin': 881,
#  '4info': 882,
#  'flower': 883,
#  'alright': 884,
#  '150pmsgrcvdhgsuite3422landsroww1j6hl': 885,
#  'freefone': 886,
#  'boytoy': 887,
#  'bx420': 888,
#  'places': 889,
#  'telling': 890,
#  '2day': 891,
#  'bus': 892,
#  '2optout': 893,
#  'txtauction': 894,
#  'complete': 895,
#  '10am7pm': 896,
#  'valentines': 897,
#  '83600': 898,
#  'guy': 899,
#  'used': 900,
#  'wanted': 901,
#  'notice': 902,
#  'cw25wx': 903,
#  'delivered': 904,
#  'moby': 905,
#  'high': 906,
#  'street': 907,
#  'pa': 908,
#  'purpose': 909,
#  'tenants': 910,
#  'refused': 911,
#  'lots': 912,
#  'medical': 913,
#  'safe': 914,
#  'omg': 915,
#  'shall': 916,
#  'den': 917,
#  'wrong': 918,
#  'num': 919,
#  'pleased': 920,
#  'urn': 921,
#  'ac': 922,
#  'largest': 923,
#  'ec2a': 924,
#  'daily': 925,
#  'birthday': 926,
#  'reveal': 927,
#  'cust': 928,
#  'simply': 929,
#  'ibiza': 930,
#  'starting': 931,
#  'yar': 932,
#  'mths': 933,
#  'ntwk': 934,
#  '08001950382': 935,
#  'bahamas': 936,
#  'aft': 937,
#  'fine': 938,
#  'makes': 939,
#  'bed': 940,
#  'fucking': 941,
#  '87131': 942,
#  '7250i': 943,
#  'roww1jhl': 944,
#  '83355': 945,
#  'added': 946,
#  'action': 947,
#  '150pmin': 948,
#  'world': 949,
#  '87239': 950,
#  'tot': 951,
#  'saying': 952,
#  '87121': 953,
#  'fr': 954,
#  'fact': 955,
#  'yo': 956,
#  'full': 957,
#  'available': 958,
#  'heard': 959,
#  'pix': 960,
#  '8552': 961,
#  'cause': 962,
#  'wiv': 963,
#  'started': 964,
#  'hav': 965,
#  'forgot': 966,
#  'done': 967,
#  'yer': 968,
#  '84199': 969,
#  'eng': 970,
#  'box39822': 971,
#  'w111wx': 972,
#  'straight': 973,
#  'rooms': 974,
#  'both': 975,
#  '3wk': 976,
#  'hit': 977,
#  'actually': 978,
#  'kept': 979,
#  'touch': 980,
#  'unable': 981,
#  'lover': 982,
#  '1500': 983,
#  'pod': 984,
#  'app': 985,
#  'exciting': 986,
#  'sign': 987,
#  'men': 988,
#  'super': 989,
#  '542': 990,
#  'run': 991,
#  'urgnt': 992,
#  '020603': 993,
#  '0808': 994,
#  '145': 995,
#  '4742': 996,
#  '9am11pm': 997,
#  '85': 998,
#  'wc1n3xx': 999}

# %%
#vectorization and normalization
def vectorize(text):
    vec = np.zeros(len(vocab))
    for word in text.split():
        if word in vocab:
            vec[vocab[word]] += 1
    return vec

X = []
for text in df['cleaned_msg']:
    X.append(vectorize(text))
X = np.array(X)
Y = df['label'].values

# %%
#training and testing split
idx = np.random.permutation(len(X))

X = X[idx]
Y = Y[idx]

split = int(0.7 * len(X))

x_train, x_test = X[:split], X[split:]
y_train, y_test = Y[:split], Y[split:]

# %% [markdown]
# ## Logistic Regression Model
# - Sigmoid for probability estimation
# - Cross-entropy loss for optimization
# - Gradient descent for parameter updates

# %%
#sigmoid and loss functions
def sigmoid(z):
    """Compute the sigmoid function"""
    return 1/(1 + np.exp(-z))

def cross_entropy_loss(y_true, p_pred):
    eps = 1e-15
    p_pred = np.clip(p_pred, eps, 1 - eps)
    return -np.mean(y_true*np.log(p_pred) + (1-y_true)*np.log(1-p_pred))

# %%
w=np.zeros(x_train.shape[1])
b=0
lr=0.1
epochs=350

# %%
for i in range(epochs):
    Z = x_train @ w + b
    p=sigmoid(Z)
    dw=(1/len(x_train)) * (x_train.T@(p-y_train))
    db=(1/len(x_train)) * np.sum(p-y_train)

    w-= lr*dw
    b-=lr*db

# %% [markdown]
# ## Evaluation Metrics
#
# The model performance is evaluated using the following metrics:
# - Confusion Matrix
# - Accuracy
# - Precision
# - Recall

# %%
#predicitons
Z = x_test @ w + b
p = sigmoid(Z)

threshold = 0.5
y_pred = (p >= threshold).astype(int)

# %%
#metrics
TP = np.sum((y_test == 1) & (y_pred == 1))
TN = np.sum((y_test == 0) & (y_pred == 0))
FP = np.sum((y_test == 0) & (y_pred == 1))
FN = np.sum((y_test == 1) & (y_pred == 0))

# %%
precision = TP / (TP + FP) if (TP + FP) != 0 else 0
recall = TP / (TP + FN) if (TP + FN) != 0 else 0
accuracy = (TP + TN) / (TP + TN + FP + FN)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
# Out:
# Accuracy: 0.9220489977728286
# Precision: 0.9393939393939394
# Recall: 0.8899521531100478

# %%
def predict_spam(text):
    text = clean_text(text)

    vec = np.zeros(len(vocab))
    for word in text.split():
        if word in vocab:
            vec[vocab[word]] += 1
    z = np.dot(vec, w) + b
    p = 1 / (1 + np.exp(-z))

    print("DEBUG → z:", z, "p:", p)  

    return "Most Likely Spam" if p >= 0.4 else "Most Likely Ham"

# %%
print(predict_spam("Congratulations! You won a free prize"))
print(predict_spam("Let's meet tomorrow at 10"))
# Out:
# DEBUG → z: 0.2733588430077034 p: 0.5679173094686406
# Most Likely Spam
# DEBUG → z: -1.244186270278363 p: 0.22370814548558712
# Most Likely Ham
